# %%
'''
Yine bir bloktan oluşur ve while döngüsü belli bir koşul sağlandığı sürece o bloğu tekrar tekrar kontrol ediyor.Bir süre sonra
sona ermesi için koşul durumunun False olması gerekir.
'''
# Out:
# '\nYine bir bloktan oluşur ve while döngüsü belli bir koşul sağlandığı sürece o bloğu tekrar tekrar kontrol ediyor.Bir süre sonra\nsona ermesi için koşul durumunun False olması gerekir.\n'

# %%
i = 0

while i < 10:
    print('i\'nin değeri {} .'.format(i))
# Out:
# i'nin değeri 0 .
# i'nin değeri 0 .
# i'nin değeri 0 .
# i'nin değeri 0 .
# i'nin değeri 0 .
# i'nin değeri 0 .
# i'nin değeri 0 .
# i'nin değeri 0 .
# i'nin değeri 0 .
# i'nin değeri 0 .
# i'nin değeri 0 .
# i'nin değeri 0 .
# i'nin değeri 0 .
# i'nin değeri 0 .
# i'nin değeri 0 .
# i'nin değeri 0 .
# i'nin değeri 0 .
# i'nin değeri 0 .
# i'nin değeri 0 .
# i'nin değeri 0 .
# i'nin değeri 0 .
# i'nin değeri 0 .
# i'nin değeri 0 .
# i'nin değeri 0 .
# i'nin değeri 0 .
# i'nin değeri 0 .
# i'nin değeri 0 .
# i'nin değeri 0 .
# i'nin değeri 0 .
# i'nin değeri 0 .
# i'nin değeri 0 .
# i'nin değeri 0 .
# i'nin değeri 0 .
# i'nin değeri 0 .
# i'nin değeri 0 .
# i'nin değeri 0 .
# i'nin değeri 0 .
# i'nin değeri 0 .
# i'nin değeri 0 .
# i'nin değeri 0 .
# i'nin değeri 0 .
# i'nin değeri 0 .
# i'nin değeri 0 .
# i'nin değeri 0 .
# i'nin değeri 0 .
# i'nin değeri 0 .
# i'nin değeri 0 .
# i'nin değeri 0 .
# i'nin değeri 0 .
# i'nin değeri 0 .
# i'nin değeri 0 .
# i'nin değeri 0 .
# ...

# %%
i = 0

while i < 10:
    print('i\'nin değeri',i)
    i  += 1
# Out:
# i'nin değeri 0
# i'nin değeri 1
# i'nin değeri 2
# i'nin değeri 3
# i'nin değeri 4
# i'nin değeri 5
# i'nin değeri 6
# i'nin değeri 7
# i'nin değeri 8
# i'nin değeri 9

# %%
i = 0

while i < 20:
    print("i'nin değeri",i)
    i +=2
# Out:
# i'nin değeri 0
# i'nin değeri 2
# i'nin değeri 4
# i'nin değeri 6
# i'nin değeri 8
# i'nin değeri 10
# i'nin değeri 12
# i'nin değeri 14
# i'nin değeri 16
# i'nin değeri 18

# %%
a = 0

while a<40:
    print("Python öğreniyorum")
    a += 1
# Out:
# Python öğreniyorum
# Python öğreniyorum
# Python öğreniyorum
# Python öğreniyorum
# Python öğreniyorum
# Python öğreniyorum
# Python öğreniyorum
# Python öğreniyorum
# Python öğreniyorum
# Python öğreniyorum
# Python öğreniyorum
# Python öğreniyorum
# Python öğreniyorum
# Python öğreniyorum
# Python öğreniyorum
# Python öğreniyorum
# Python öğreniyorum
# Python öğreniyorum
# Python öğreniyorum
# Python öğreniyorum
# Python öğreniyorum
# Python öğreniyorum
# Python öğreniyorum
# Python öğreniyorum
# Python öğreniyorum
# Python öğreniyorum
# Python öğreniyorum
# Python öğreniyorum
# Python öğreniyorum
# Python öğreniyorum
# Python öğreniyorum
# Python öğreniyorum
# Python öğreniyorum
# Python öğreniyorum
# Python öğreniyorum
# Python öğreniyorum
# Python öğreniyorum
# Python öğreniyorum
# Python öğreniyorum
# Python öğreniyorum

# %%
a = 0

while a < 42:
    print('Maşallah')
    a += 1 #41 kere maşalla
# Out:
# Maşallah
# Maşallah
# Maşallah
# Maşallah
# Maşallah
# Maşallah
# Maşallah
# Maşallah
# Maşallah
# Maşallah
# Maşallah
# Maşallah
# Maşallah
# Maşallah
# Maşallah
# Maşallah
# Maşallah
# Maşallah
# Maşallah
# Maşallah
# Maşallah
# Maşallah
# Maşallah
# Maşallah
# Maşallah
# Maşallah
# Maşallah
# Maşallah
# Maşallah
# Maşallah
# Maşallah
# Maşallah
# Maşallah
# Maşallah
# Maşallah
# Maşallah
# Maşallah
# Maşallah
# Maşallah
# Maşallah
# Maşallah
# Maşallah

# %%
liste = [1,2,3,4]

for i in liste:
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
liste = [1,2,3,4]
index = 0

while index < len(liste):
    print("index ",index,"Liste elemanı",liste[index])
    index += 1
# Out:
# index  0 Liste elemanı 1
# index  1 Liste elemanı 2
# index  2 Liste elemanı 3
# index  3 Liste elemanı 4
